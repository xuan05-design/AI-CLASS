# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ abalone.ipynb')
df.head()
# Out:
# Empty DataFrame
# ...

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')

# Correct the path to read 'abalone.csv' from Google Drive
# Assuming 'abalone.csv' is directly in MyDrive
df = pd.read_ipynb('/content/drive/MyDrive/abalone.ipynb')

# Assign column names as the CSV was loaded without a header
df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings']

from sklearn.preprocessing import LabelEncoder

# Display DataFrame columns to check for 'Sex' column
print(df.columns)

le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11439/2651965777.py in <cell line: 0>()
#       7 # Correct the path to read 'abalone.csv' from Google Drive
#       8 # Assuming 'abalone.csv' is directly in MyDrive
# ----> 9 df = pd.read_ipynb('/content/drive/MyDrive/abalone.ipynb')
#      10
#      11 # Assign column names as the CSV was loaded without a header
#
# AttributeError: module 'pandas' has no attribute 'read_ipynb'

# %%
import subprocess
result = subprocess.run(['head', '-n', '5', '/content/abalone.csv'], capture_output=True, text=True)
print(result.stdout)

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'drive', 'sample_data']

# %%
df.to_csv('abalone.csv', index=False)

# %%
corr = df.corr()
corr
# Out:
#                                                    {"nbformat":4  \
# {"nbformat":4                                                NaN
# nbformat_minor:0                                             NaN
# metadata:{"colab":{"provenance":[]                           NaN
# mount_file_id:"16PhqAQGQB_ugUvJap2OMzp8s59Uqb14y"            NaN
# authorship_tag:"ABX9TyMRLIhuVQHAfYfWlhwcNMUM"}               NaN
# ...                                                          ...
# {"cell_type":"code".9                                        NaN
# source:[].3                                                  NaN
# metadata:{"id":"JrE3CUQpGWK3"}                               NaN
# execution_count:null.13                                      NaN
# outputs:[]}]}                                                NaN
#
#                                                    nbformat_minor:0  \
# {"nbformat":4                                                   NaN
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 54732 (\N{HANGUL SYLLABLE HEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 52980 (\N{HANGUL SYLLABLE KEOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# ...

# %%
X = df.drop('Rings', axis=1)
y = df['Rings']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_11439/3302653526.py in <cell line: 0>()
# ----> 1 X = df.drop('Rings', axis=1)
#       2 y = df['Rings']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11439/80869000.py in <cell line: 0>()
#       2
#       3 X_train, X_test, y_train, y_test = train_test_split(
# ----> 4     X, y, test_size=0.2
#       5 )
#
# NameError: name 'X' is not defined

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11439/766854246.py in <cell line: 0>()
#       3 scaler = StandardScaler()
#       4
# ----> 5 X_train = scaler.fit_transform(X_train)
#       6 X_test = scaler.transform(X_test)
#
# NameError: name 'X_train' is not defined
